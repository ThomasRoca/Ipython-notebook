# %% [markdown]
# #<span style="color:#285c8c"><big>&#9733; "Country at a Glance"  generator 1.0 &#9733;</span><big><span style="color:#00acee;"><i>  [BIIIIMMM!!!]
# <br>
# ![image](http://www.stats4dev.com/prez/images/generator.png)
# <br>
#
# &#9733;<i>Thomas Roca, PhD - AFD Research Direction &#9733;<br>
# *Version october 4th 2015*
#
# ------------------

# %% [markdown]
# ### What it does:
# This script generates web pages looping on country iso3 identifier.The web page contains HTML table displaying data from json databases. It uses javascript.
#
# http://www.stats4dev.com/glance/glance_BRA.html
#
# ---

# %%
from string import Template
from IPython.display import HTML

#all
#AMR isolist=['DZA','PER','PHL','DZA','SUR','BOL','MOZ','LKA','TZA','ZMB','BGD','BEN','BFA','ECU','UGA','COG','ETH','MRT','RWA','TGO','GIN','LBR','MDG','MLI','NER','TCD','CAF','COD']
isolist=['ABW', 'AFG', 'AGO', 'ALB', 'AND', 'ARE', 'ARG', 'ARM', 'ASM', 'ATG', 'AUS', 'AUT', 'AZE', 'BDI', 'BEL', 'BEN', 'BFA', 'BGD', 'BGR', 'BHR', 'BHS', 'BIH', 'BLR', 'BLZ', 'BMU', 'BOL', 'BRA', 'BRB', 'BRN', 'BTN', 'BWA', 'CAF', 'CAN', 'CHE', 'CHL', 'CHN', 'CIV', 'CMR', 'COD', 'COG', 'COL', 'COM', 'CPV', 'CRI', 'CUB', 'CUW', 'CYM', 'CYP', 'CZE', 'DEU', 'DJI', 'DMA', 'DNK', 'DOM', 'DZA', 'ECU', 'EGY', 'ERI', 'ESP', 'EST', 'ETH', 'FIN', 'FJI', 'FRA', 'FRO', 'FSM', 'GAB', 'GBR', 'GEO', 'GHA', 'GIN', 'GMB', 'GNB', 'GNQ', 'GRC', 'GRD', 'GRL', 'GTM', 'GUM', 'GUY', 'HKG', 'HND', 'HRV', 'HTI', 'HUN', 'IDN', 'IMN', 'IND', 'IRL', 'IRN', 'IRQ', 'ISL', 'ITA', 'ISR', 'JAM', 'JOR', 'JPN', 'KAZ', 'KEN', 'KGZ', 'KHM', 'KNA', 'KOR', 'KWT', 'LAO', 'LBN', 'LBR', 'LBY', 'LCA', 'LIE', 'LKA', 'LSO', 'LTU', 'LUX', 'LVA', 'MAC', 'MAF', 'MAR', 'MCO', 'MDA', 'MDG', 'MDV', 'MEX', 'MHL', 'MKD', 'MLI', 'MLT', 'MMR', 'MNE', 'MNG', 'MNP', 'MOZ', 'MRT', 'MUS', 'MWI', 'MYS', 'NAM', 'NCL', 'NER', 'NGA', 'NIC', 'NLD', 'NOR', 'NPL', 'NZL', 'OMN', 'PAK', 'PAN', 'PER', 'PHL', 'PLW', 'PNG', 'POL', 'PRI', 'PRT', 'PRY', 'PSE', 'PYF', 'QAT', 'ROU', 'RUS', 'RWA', 'SAU', 'SDN', 'SEN', 'SGP', 'SLB', 'SLE', 'SLV', 'SMR', 'SOM', 'SRB', 'SSD', 'STP', 'SUR', 'SVK', 'SVN', 'SWE', 'SWZ', 'SXM', 'SYC', 'SYR', 'TCA', 'TCD', 'TGO', 'THA', 'TJK', 'TKM', 'TLS', 'TON', 'TTO', 'TUN', 'TUR', 'TUV', 'TWN', 'TZA', 'UGA', 'UKR', 'URY', 'USA', 'UZB', 'VCT', 'VEN', 'VIR', 'VNM', 'VUT', 'WSM', 'YEM', 'ZAF', 'ZMB', 'ZWE']


#Loop over isolist
for iso3 in isolist:
    #What will be substitute in the template function
    Input = {'iso3':iso3}
    
    #Starting HTML code
    html='''
    <!DOCTYPE html>
    <html>
    <head>
    <meta http-equiv="content-type" content="text/html; charset=iso-8859-1">
    <title>At a glance, AFD</title>
    <script type='text/javascript' src='//code.jquery.com/jquery-1.9.1.js'></script>
    
    <style type='text/css'>
    
    table, th, td {
    border: 0px solid black; border-collapse: collapse; font-family:Calibri; font-size:11pt;
    }
    
    th, td {
    padding: 5px; text-align: left; border-bottom: 1px solid #f1f1f1;
    }
    
    #pov, #mort,#esp_vie,#pib_pc, #Pop_active_g,#Pop,#Pop_date, #Pop1,#Pop1_date, #Pop2,#Pop2_date, #Pop3,#Pop3_date,#Pop_g ,#Pop_g_date, #urban_pop, #urban_pop_date{width:75px;
    }

    #frame {
     width: 25%;  height: 2500px; left:5px; top:0px; position: absolute; background: none; border-style: none;
    }

    .dataviz {
     width: 100%; height: 410px; left:5px; top:150px; position: relative; border-style: none;
    }
    
    img { position: absolute;    left: 10px;    top: 10px;    z-index: -1;
    }

    h1 {
    position: relative; left: 110px;    top: 20px;
    }

    </style>

    <script type='text/javascript'>
    
    window.onload=function(){
         
    $.getJSON("http://afd.countrydashboards.com/glance/data/WB_WDI_$iso3.json", function (json) {
    
    //country name
        var country= json["$iso3"]["country"] ;
        $('#country').text(country);

    //Population (millions)
        var Pop_date= json["SP.POP.TOTL"]["YearMax"];
        if(Pop_date.charAt){$('#Pop_date').text('no data');} else {
            $('#Pop_date').text(Pop_date);
            var value="$iso3"+Pop_date;
            var Pop = json["SP.POP.TOTL"][value];
            // toLocaleString() function allows separating thousands
            if(Pop.charAt){$('#Pop').text('no data');}else{$('#Pop').text(Pop.toLocaleString());}
        }
        
    //Répartition population par âge (en % de la population totale)
        var Pop1_date= json["SP.POP.0014.TO.ZS"]["YearMax"] ;
        if(Pop1_date.charAt){$('#Pop1_date').text('no data');} else {
            $('#Pop1_date').text(Pop1_date);
            var value="$iso3"+Pop1_date;
            var Pop1 = json["SP.POP.0014.TO.ZS"][value];
            if(Pop1.charAt){$('#Pop1').text('no data');}else{$('#Pop1').text(Pop1.toPrecision(4)+' %');}
        }
        var Pop2_date= json["SP.POP.1564.TO.ZS"]["YearMax"] ;
        if(Pop2_date.charAt){$('#Pop2_date').text('no data');} else {
            $('#Pop2_date').text(Pop2_date);
            var value="$iso3"+Pop2_date;
            var Pop2 = json["SP.POP.1564.TO.ZS"][value];
            if(Pop2.charAt){$('#Pop2').text('no data');}else{$('#Pop2').text(Pop2.toPrecision(4)+' %');}
        }
        var Pop3_date= json["SP.POP.65UP.TO.ZS"]["YearMax"] ;
        if(Pop3_date.charAt){$('#Pop3_date').text('no data');} else {
            $('#Pop3_date').text(Pop3_date);
            var value="$iso3"+Pop3_date;
            var Pop3 = json["SP.POP.65UP.TO.ZS"][value];
            if(Pop3.charAt){$('#Pop3').text('no data');}else{$('#Pop3').text(Pop3.toPrecision(4)+' %');}
        }
        
    //Croissance annuelle moyenne de la population (moy. 4 dernières années dispo)
        var Pop_g_date= json["SP.POP.TOTL"]["YearMax"] ;
        if( Pop_g_date.charAt){$('#Pop_g_date').text('no data');} else {
            $('#Pop_g_date').text(Pop_g_date);

            var value="$iso3"+Pop_g_date;
            var value1="$iso3"+(Pop_g_date-1);
            var value2="$iso3"+(Pop_g_date-2);
            var value3="$iso3"+(Pop_g_date-3);

            var Pop_g = 1/3*100*(((json["SP.POP.TOTL"][value]-json["SP.POP.TOTL"][value1])/json["SP.POP.TOTL"][value1])+ ((json["SP.POP.TOTL"][value1]-json["SP.POP.TOTL"][value2])/json["SP.POP.TOTL"][value2])+((json["SP.POP.TOTL"][value2]-json["SP.POP.TOTL"][value3])/json["SP.POP.TOTL"][value3]));
            if(Pop_g.charAt){$('#Pop_g').text('no data');}else{$('#Pop_g').text(Pop_g.toPrecision(4)+' %');}
        }
        
    //Croissance annuelle moyenne de la population active (moy. 4 dernières années dispo)
        var Pop_active_g_date = json["SL.TLF.ACTI.1524.NE.ZS"]["YearMax"] ;
        if( Pop_active_g_date.charAt){$('#Pop_active_g_date').text('no data');} else {
            $('#Pop_active_g_date').text(Pop_active_g_date);

            var value="$iso3"+Pop_active_g_date;
            var value1="$iso3"+(Pop_active_g_date-1);
            var value2="$iso3"+(Pop_active_g_date-2);
            var value3="$iso3"+(Pop_active_g_date-3);

            var Pop_active_g = 1/3*100*(((json["SL.TLF.ACTI.1524.NE.ZS"][value]-json["SL.TLF.ACTI.1524.NE.ZS"][value1])/json["SL.TLF.ACTI.1524.NE.ZS"][value1])+ ((json["SL.TLF.ACTI.1524.NE.ZS"][value1]-json["SL.TLF.ACTI.1524.NE.ZS"][value2])/json["SL.TLF.ACTI.1524.NE.ZS"][value2])+((json["SL.TLF.ACTI.1524.NE.ZS"][value2]-json["SL.TLF.ACTI.1524.NE.ZS"][value3])/json["SL.TLF.ACTI.1524.NE.ZS"][value3]));
            if(Pop_active_g.charAt){$('#Pop_active_g').text('no data');}else{$('#Pop_active_g').text(Pop_active_g.toPrecision(4)+' %');}
        }
        
    //Population urbaine (% de la population totale)
        var urban_pop_date= json["SP.URB.TOTL.IN.ZS"]["YearMax"] ;
        if( urban_pop_date.charAt){$('#urban_pop_date').text('no data');} else {
            $('#urban_pop_date').text(urban_pop_date);
            var value="$iso3"+urban_pop_date;
            var urban_pop = json["SP.URB.TOTL.IN.ZS"][value];
            if(urban_pop.charAt){$('#urban_pop').text('no data');}else{$('#urban_pop').text(urban_pop.toPrecision(4)+' %');}
        }
        
    // PIB par habitant (US$ current)
        var pib_pc_date= json["NY.GDP.PCAP.CD"]["YearMax"] ;
        if(pib_pc_date.charAt){$('#pib_pc_date').text('no data');} else {
            $('#pib_pc_date').text(pib_pc_date); 
            var value="$iso3"+pib_pc_date;
            var pib_pc= json["NY.GDP.PCAP.CD"][value] ;
            if(pib_pc.charAt){$('#pib_pc').text('no data');}else{$('#pib_pc').text(pib_pc.toPrecision(7));}
        }

    // PIB cap PPA2011 us
        var pib_pcppa_date= json["NY.GDP.PCAP.PP.KD"]["YearMax"] ;
        if(pib_pcppa_date.charAt){$('#pib_pcppa_date').text('no data');} else {
            $('#pib_pcppa_date').text(pib_pcppa_date); 
            var value="$iso3"+pib_pcppa_date;
            var pib_pcppa= json["NY.GDP.PCAP.PP.KD"][value] ;
            if(pib_pcppa.charAt){$('#pib_pcppa').text('no data');}else{$('#pib_pcppa').text(pib_pcppa.toPrecision(7));}
        }
        
    //Poverty (national line head count) SI.POV.NAHC
        var pov_date= json["SI.POV.NAHC"]["YearMax"] ;
        if(pov_date.charAt){$('#pov_date').text('no data');} else {
            $('#pov_date').text(pov_date);
            var value="$iso3"+pov_date;
            var pov= json["SI.POV.NAHC"][value] ;
            if(pov.charAt){$('#pov').text('no data');}else{$('#pov').text(pov.toPrecision(4)+' %');}
        }

    //Life expectancy at birth, total (years) = SP.DYN.LE00.IN
        var esp_vie_date= json["SP.DYN.LE00.IN"]["YearMax"] ;
        if(esp_vie_date.charAt){$('#esp_vie_date').text('no data');} else {
            $('#esp_vie_date').text(esp_vie_date); 
            var value="$iso3"+esp_vie_date;
            var esp_vie= json["SP.DYN.LE00.IN"][value] ;
            if(esp_vie.charAt){$('#esp_vie').text('no data');}else{$('#esp_vie').text(esp_vie.toPrecision(4));}
        }
        
    //Mortality rate, infant ($iso3 1,000 live births) = SP.DYN.IMRT.IN
        var mort_date= json["SP.DYN.IMRT.IN"]["YearMax"] ;
        if(mort_date.charAt){$('#mort_date').text('no data');} else {
            $('#mort_date').text(mort_date);
            var value="$iso3"+mort_date;
            var mort= json["SP.DYN.IMRT.IN"][value] ;
            if(mort.charAt){$('#mort').text('no data');}else{$('#mort').text(mort.toPrecision(4));}
        }
        
    //Improved water source (% of population with access) = SH.H2O.SAFE.ZS
        var water_date= json["SH.H2O.SAFE.ZS"]["YearMax"] ;
        if(water_date.charAt){$('#water_date').text('no data');} else {
            $('#water_date').text(water_date); 
            var value="$iso3"+water_date;
            var water= json["SH.H2O.SAFE.ZS"][value] ;
            if(water.charAt){$('#water').text('no data');}else{$('#water').text(water.toPrecision(4)+' %');}
        }

    //Analphabestisme = 100 - Literacy rate, adult total (% of people ages 15 and above) = 100-SE.ADT.LITR.ZS
        var literacy_date= json["SE.ADT.LITR.ZS"]["YearMax"] ;
        if(literacy_date.charAt){$('#literacy_date').text('no data');} else {
            $('#literacy_date').text(literacy_date); 
            var value="$iso3"+literacy_date;
            var literacy=(100-json["SE.ADT.LITR.ZS"][value]);
            if(literacy.charAt){$('#literacy').text('no data');}else{$('#literacy').text(literacy.toPrecision(4)+' %');}
        }
        
    //School enrollment, primary (% gross) = SE.PRM.ENRR
        var school_date= json["SE.PRM.ENRR"]["YearMax"] ;
        if(school_date.charAt){$('#school_date').text('no data');} else {
            $('#school_date').text(school_date); 
            var value="$iso3"+school_date;
            var school=json["SE.PRM.ENRR"][value] ;
            if(school.charAt){$('#school').text('no data');}else{$('#school').text(school.toPrecision(4)+' %');}
        }
        
    //Unemployment, total (% of total labor force) (modeled ILO estimate) = SL.UEM.TOTL.ZS
        var unemployment_date= json["SL.UEM.TOTL.ZS"]["YearMax"] ;
        if(unemployment_date.charAt){$('#unemployment_date').text('no data');} else {
            $('#unemployment_date').text(unemployment_date); 
            var value="$iso3"+unemployment_date;
            var unemployment=json["SL.UEM.TOTL.ZS"][value] ;
            if(unemployment.charAt){$('#unemployment').text('no data');}else{$('#unemployment').text(unemployment.toPrecision(3)+' %');}
        }
        
    //HDI rank

    //Structure de l'économie (% du PIB) = NV.AGR.TOTL.ZS
        var share_agri_date= json["NV.AGR.TOTL.ZS"]["YearMax"] ;
        if(share_agri_date.charAt){$('#share_agri_date').text('no data');} else {
            $('#share_agri_date').text(share_agri_date); 
            var value="$iso3"+share_agri_date;
            var share_agri=json["NV.AGR.TOTL.ZS"][value] ;
            if(share_agri.charAt){$('#share_agri').text('no data');}else{$('#share_agri').text(share_agri.toPrecision(3)+' %');}
        }

    //Industry = NV.IND.TOTL.ZS
        var share_indust_date= json["NV.IND.TOTL.ZS"]["YearMax"] ;
        if(share_indust_date.charAt){$('#share_indust_date').text('no data');} else {
            $('#share_indust_date').text(share_indust_date);
            var value="$iso3"+share_indust_date;
            var share_indust=json["NV.IND.TOTL.ZS"][value] ;
            if(share_indust.charAt){$('#share_indust').text('no data');}else{$('#share_indust').text(share_indust.toPrecision(3)+' %');}
        }
        
    //Services, etc., value added (% of GDP) =  NV.SRV.TETC.ZS
        var share_serv_date= json["NV.SRV.TETC.ZS"]["YearMax"] ;
        if(share_serv_date.charAt){$('#share_serv_date').text('no data');} else {
            $('#share_serv_date').text(share_serv_date);
            var value="$iso3"+share_serv_date;
            var share_serv=json["NV.SRV.TETC.ZS"][value] ;
            if(share_serv.charAt){$('#share_serv').text('no data');}else{$('#share_serv').text(share_serv.toPrecision(3)+' %');}
        }
        
    //GDP (current LCU) = NY.GDP.MKTP.CN /1000000000
        var GDP_LCU_date= json["NY.GDP.MKTP.CN"]["YearMax"] ;
        if(GDP_LCU_date.charAt){$('#GDP_LCU_date').text('no data');} else {
            $('#GDP_LCU_date').text(GDP_LCU_date);
            var value="$iso3"+GDP_LCU_date;
            var GDP_LCU=(json["NY.GDP.MKTP.CN"][value])/(1000000000);
            if(GDP_LCU.charAt){$('#GDP_LCU').text('no data');}else{$('#GDP_LCU').text(GDP_LCU.toPrecision(8));}
        }
        
    //GDP (current $) = NY.GDP.MKTP.CD
        var GDP_PPP_date= json["NY.GDP.MKTP.CD"]["YearMax"] ;
        if(GDP_PPP_date.charAt){$('#GDP_PPP_date').text('no data');} else {
            $('#GDP_PPP_date').text(GDP_PPP_date);
            var value="$iso3"+GDP_PPP_date;
            var GDP_PPP=json["NY.GDP.MKTP.CD"][value] / (1000000000);
            if(GDP_PPP.charAt){$('#GDP_PPP').text('no data');}else{$('#GDP_PPP').text(GDP_PPP.toPrecision(8));}
        }
        
    //Imports of goods and services (current US$) = NE.IMP.GNFS.CD
        var importGS_date= json["NE.IMP.GNFS.CD"]["YearMax"] ;
        if(importGS_date.charAt){$('#importGS_date').text('no data');} else {
            var value="$iso3"+importGS_date;
            var importGS=json["NE.IMP.GNFS.CD"][value] ;

        //Exports of goods and services (current US$) = NE.EXP.GNFS.CD
            var exportGS_date= json["NE.EXP.GNFS.CD"]["YearMax"] ;
            var value="$iso3"+exportGS_date;
            var exportGS=json["NE.EXP.GNFS.CD"][value] ;
            var ouverture=  ((exportGS + importGS))/(json["NY.GDP.MKTP.CD"][value])*100
            if(ouverture.charAt){$('#ouverture').text('no data');}else{$('#ouverture').text(ouverture.toPrecision(3)+' %');}
            var ouverture_date=importGS_date
            $('#ouverture_date').text(ouverture_date); 
       }
       
   //GDP (current US$) = NY.GDP.MKTP.CD
        var GDPcurr_date= json["NY.GDP.MKTP.CD"]["YearMax"] ;
        if(GDPcurr_date.charAt){$('#GDPcurr_date').text('no data');} else {
            $('#GDPcurr_date').text(GDPcurr_date); 
            var value="$iso3"+GDPcurr_date;
            var GDPcurr=json["NY.GDP.MKTP.CD"][value] ;
            if(GDPcurr.charAt){$('#GDPcurr').text('no data');}else{$('#GDPcurr').text(GDPcurr);}
        }
        
    //Exports as a capacity to import (constant LCU) = NY.EXP.CAPM.KN
        var exp_imp_date= json["NY.EXP.CAPM.KN"]["YearMax"] ;
        if(exp_imp_date.charAt){$('#exp_imp_date').text('no data');} else {
            $('#exp_imp_date').text(exp_imp_date);
            var value="$iso3"+exp_imp_date;
            var exp_imp=json["NY.EXP.CAPM.KN"][value]/1000000000 ;
            if(exp_imp.charAt){$('#exp_imp').text('no data');}else{$('#exp_imp').text(exp_imp.toPrecision(8));}
        }
        
    //Total reserves in months of imports = FI.RES.TOTL.MO
        var reserve_date= json["FI.RES.TOTL.MO"]["YearMax"] ;
        if(reserve_date.charAt){$('#reserve_date').text('no data');} else {
            $('#reserve_date').text(reserve_date);
            var value="$iso3"+reserve_date;
            var reserve=json["FI.RES.TOTL.MO"][value];
            if(reserve.charAt){$('#reserve').text('no data');}else{$('#reserve').text(reserve);}
        }

    //Central government debt, total (% of GDP) = GC.DOD.TOTL.GD.ZS
        var debt_date= json["GC.DOD.TOTL.GD.ZS"]["YearMax"] ;
        if(debt_date.charAt){$('#debt_date').text('no data');} else {
           $('#debt_date').text(debt_date);
           var value="$iso3"+debt_date;
           var debt=json["GC.DOD.TOTL.GD.ZS"][value] ;
           if(debt.charAt){$('#debt').text('no data');}else{$('#debt').text(debt.toPrecision(5)+' %');}
        }
        
    //External debt stocks (% of GNI) = DT.DOD.DECT.GN.ZS
        var ext_debt_date= json["DT.DOD.DECT.GN.ZS"]["YearMax"] ;
        if(ext_debt_date.charAt){$('#ext_debt_date').text('no data');} else {
           $('#ext_debt_date').text(ext_debt_date); 
           var value="$iso3"+ext_debt_date;
           var ext_debt=json["DT.DOD.DECT.GN.ZS"][value] ;
           if(ext_debt.charAt){$('#ext_debt').text('no data');}else{$('#ext_debt').text(ext_debt.toPrecision(5)+' %');}
        }

    //===============================================> TIME SERIES  <===========================================================

    //GDP growth (annual %) = NY.GDP.MKTP.KD.ZG
        var GDPg_date= json["NY.GDP.MKTP.KD.ZG"]["YearMax"] ;
        if(GDPg_date.charAt){$('#GDPg_date').text('no data');} else {
            $('#GDPg_date').text(GDPg_date); 
            var value="$iso3"+GDPg_date;
            var GDPg=json["NY.GDP.MKTP.KD.ZG"][value] ;
            if(GDPg.charAt){$('#GDPg').text('no data');}else{$('#GDPg').html('<b>'+GDPg_date + '</b><br/>'+ GDPg.toPrecision(3)+' %');}
        }
    //year minus 1
    if(GDPg_date.charAt){$('#GDPg_date').text('no data');} else {     // fix the problem that occurs when there's no data at all
        var GDPg_date_m1= (json["NY.GDP.MKTP.KD.ZG"]["YearMax"]) -1;
        if(GDPg_date_m1.charAt){$('#GDPg_date_m1').text('no data');} else {
            $('#GDPg_date_m1').text(GDPg_date_m1);
            var value="$iso3"+GDPg_date_m1;
            var GDPg_m1=json["NY.GDP.MKTP.KD.ZG"][value] ;
            if(GDPg_m1.charAt){$('#GDPg_m1').text('no data');}else{$('#GDPg_m1').html('<b>'+GDPg_date_m1 + '</b><br/>'+ GDPg_m1.toPrecision(3)+' %');}
        }
    }
    //year minus 2
    if(GDPg_date.charAt){$('#GDPg_date').text('no data');} else {
        var GDPg_date_m2= (json["NY.GDP.MKTP.KD.ZG"]["YearMax"]) -2;
        if(GDPg_date_m2.charAt){$('#GDPg_date_m2').text('no data');} else {
            $('#GDPg_date_m2').text(GDPg_date_m2);
            var value="$iso3"+GDPg_date_m2;
            var GDPg_m2=json["NY.GDP.MKTP.KD.ZG"][value] ;
            if(GDPg_m2.charAt){$('#GDPg_m2').text('no data');}else{$('#GDPg_m2').html('<b>'+GDPg_date_m2 + '</b><br/>'+ GDPg_m2.toPrecision(3)+' %');}
        }
    }
    //year minus 3
        var GDPg_date_m3= (json["NY.GDP.MKTP.KD.ZG"]["YearMax"]) -3;
        if(GDPg_date_m3.charAt){$('#GDPg_date_m3').text('no data');} else {
            $('#GDPg_date_m3').text(GDPg_date_m3);
            var value="$iso3"+GDPg_date_m3;
            var GDPg_m3=json["NY.GDP.MKTP.KD.ZG"][value] ;
            if(GDPg_m3.charAt){$('#GDPg_m3').text('no data');}else{$('#GDPg_m3').html('<b>'+GDPg_date_m3 + '</b><br/>'+ GDPg_m3.toPrecision(3)+' %');}
        }
    //year minus 4
     if(GDPg_date.charAt){$('#GDPg_date').text('no data');} else {
         var GDPg_date_m4= (json["NY.GDP.MKTP.KD.ZG"]["YearMax"]) -4;
        if(GDPg_date_m4.charAt){$('#GDPg_date_m4').text('no data');} else {
            $('#GDPg_date_m4').text(GDPg_date_m4);
            var value="$iso3"+GDPg_date_m4;
            var GDPg_m4=json["NY.GDP.MKTP.KD.ZG"][value] ;
            if(GDPg_m4.charAt){$('#GDPg_m4').text('no data');}else{$('#GDPg_m4').html('<b>'+GDPg_date_m4 + '</b><br/>'+ GDPg_m4.toPrecision(3)+' %');}
        }
    }
    //=============================================================================
    //GDP $iso3 capita growth (annual %) = NY.GDP.PCAP.KD.ZG

        var GDP_PCg_date= json["NY.GDP.PCAP.KD.ZG"]["YearMax"] ;
        if(GDP_PCg_date.charAt){$('#GDP_PCg_date').text('no data');} else {
            $('#GDP_PCg_date').text(GDP_PCg_date); 
            var value="$iso3"+GDP_PCg_date;
            var GDP_PCg=json["NY.GDP.PCAP.KD.ZG"][value] ;
            if(GDP_PCg.charAt){$('#GDP_PCg').text('no data');}else{$('#GDP_PCg').html('<b>'+GDP_PCg_date + '</b><br/>'+ GDP_PCg.toPrecision(3)+' %');}
        }
    //year minus 1
    if(GDP_PCg_date.charAt){$('#GDP_PCg_date').text('no data');} else {
        var GDP_PCg_date_m1= (json["NY.GDP.PCAP.KD.ZG"]["YearMax"]) -1;
        if(GDP_PCg_date_m1.charAt){$('#GDP_PCg_date_m1').text('no data');} else {
            $('#GDP_PCg_date_m1').text(GDP_PCg_date_m1);
            var value="$iso3"+GDP_PCg_date_m1;
            var GDP_PCg_m1=json["NY.GDP.PCAP.KD.ZG"][value] ;
            if(GDP_PCg_m1.charAt){$('#GDP_PCg_m1').text('no data');}else{$('#GDP_PCg_m1').html('<b>'+GDP_PCg_date_m1 + '</b><br/>'+ GDP_PCg_m1.toPrecision(3)+' %');}
        }
    }
    //year minus 2
    if(GDP_PCg_date.charAt){$('#GDP_PCg_date').text('no data');} else {
        var GDP_PCg_date_m2= (json["NY.GDP.PCAP.KD.ZG"]["YearMax"]) -2;
        if(GDP_PCg_date_m2.charAt){$('#GDP_PCg_date_m2').text('no data');} else {
            $('#GDP_PCg_date_m2').text(GDP_PCg_date_m2);
            var value="$iso3"+GDP_PCg_date_m2;
            var GDP_PCg_m2=json["NY.GDP.PCAP.KD.ZG"][value] ;
            if(GDP_PCg_m2.charAt){$('#GDP_PCg_m2').text('no data');}else{$('#GDP_PCg_m2').html('<b>'+GDP_PCg_date_m2 + '</b><br/>'+ GDP_PCg_m2.toPrecision(3)+' %');}
        }
    }
    //year minus 3
    if(GDP_PCg_date.charAt){$('#GDP_PCg_date').text('no data');} else {
        var GDP_PCg_date_m3= (json["NY.GDP.PCAP.KD.ZG"]["YearMax"]) -3;
        if(GDP_PCg_date_m3.charAt){$('#GDP_PCg_date_m3').text('no data');} else {
            $('#GDP_PCg_date_m3').text(GDP_PCg_date_m3);
            var value="$iso3"+GDP_PCg_date_m3;
            var GDP_PCg_m3=json["NY.GDP.PCAP.KD.ZG"][value] ;
            if(GDP_PCg_m3.charAt){$('#GDP_PCg_m3').text('no data');}else{$('#GDP_PCg_m3').html('<b>'+GDP_PCg_date_m3 + '</b><br/>'+ GDP_PCg_m3.toPrecision(3)+' %');}
        }
    }
    //year minus 4
    if(GDP_PCg_date.charAt){$('#GDP_PCg_date').text('no data');} else {
        var GDP_PCg_date_m4= (json["NY.GDP.PCAP.KD.ZG"]["YearMax"]) -4;
        if(GDP_PCg_date_m4.charAt){$('#GDP_PCg_date_m4').text('no data');} else {
            $('#GDP_PCg_date_m4').text(GDP_PCg_date_m4);
            var value="$iso3"+GDP_PCg_date_m4;
            var GDP_PCg_m4=json["NY.GDP.PCAP.KD.ZG"][value] ;
            if(GDP_PCg_m4.charAt){$('#GDP_PCg_m4').text('no data');}else{$('#GDP_PCg_m4').html('<b>'+GDP_PCg_date_m4 + '</b><br/>'+ GDP_PCg_m4.toPrecision(3)+' %');}
        }
    }
    
    //=============================================================================
    //Gross capital formation (% of GDP) = NE.GDI.TOTL.ZS

        var invest_date= json["NE.GDI.TOTL.ZS"]["YearMax"] ;
        if(invest_date.charAt){$('#invest_date').text('no data');} else {
            $('#invest_date').text(invest_date); 
            var value="$iso3"+invest_date;
            var invest=json["NE.GDI.TOTL.ZS"][value] ;
            if(invest.charAt){$('#invest').text('no data');}else{$('#invest').html('<b>'+invest_date + '</b><br/>'+ invest.toPrecision(3)+' %');}
        }
    //year minus 1
    if(invest_date.charAt){$('#invest_date').text('no data');} else {
        var invest_date_m1= (json["NE.GDI.TOTL.ZS"]["YearMax"]) -1;
        if(invest_date_m1.charAt){$('#invest_date_m1').text('no data');} else {
            $('#invest_date_m1').text(invest_date_m1);
            var value="$iso3"+invest_date_m1;
            var invest_m1=json["NE.GDI.TOTL.ZS"][value] ;
            if(invest_m1.charAt){$('#invest_m1').text('no data');}else{$('#invest_m1').html('<b>'+invest_date_m1 + '</b><br/>'+ invest_m1.toPrecision(3)+' %');}
        }
    }
    //year minus 2
    if(invest_date.charAt){$('#invest_date').text('no data');} else {
        var invest_date_m2= (json["NE.GDI.TOTL.ZS"]["YearMax"]) -2;
        if(invest_date_m2.charAt){$('#invest_date_m2').text('no data');} else {
            $('#invest_date_m2').text(invest_date_m2);
            var value="$iso3"+invest_date_m2;
            var invest_m2=json["NE.GDI.TOTL.ZS"][value] ;
            if(invest_m2.charAt){$('#invest_m2').text('no data');}else{$('#invest_m2').html('<b>'+invest_date_m2 + '</b><br/>'+ invest_m2.toPrecision(3)+' %');}
        }
    }
    //year minus 3
        var invest_date_m3= (json["NE.GDI.TOTL.ZS"]["YearMax"]) -3;
        if(invest_date_m3.charAt){$('#invest_date_m3').text('no data');} else {
            $('#invest_date_m3').text(invest_date_m3);
            var value="$iso3"+invest_date_m3;
            var invest_m3=json["NE.GDI.TOTL.ZS"][value] ;
            if(invest_m3.charAt){$('#invest_m3').text('no data');}else{$('#invest_m3').html('<b>'+invest_date_m3 + '</b><br/>'+ invest_m3.toPrecision(3)+' %');}
        }
    //year minus 4
    if(invest_date.charAt){$('#invest_date').text('no data');} else {
        var invest_date_m4= (json["NE.GDI.TOTL.ZS"]["YearMax"]) -4;
        if(invest_date_m4.charAt){$('#invest_date_m4').text('no data');} else {
            $('#invest_date_m4').text(invest_date_m4);
            var value="$iso3"+invest_date_m4;
            var invest_m4=json["NE.GDI.TOTL.ZS"][value] ;
            if(invest_m4.charAt){$('#invest_m4').text('no data');}else{$('#invest_m4').html('<b>'+invest_date_m4 + '</b><br/>'+ invest_m4.toPrecision(3)+' %');}
        }
    }
    //=============================================================================
    //Gross savings (% of GDP) = NY.GNS.ICTR.ZS

        var saving_date= json["NY.GNS.ICTR.ZS"]["YearMax"] ;
        if(saving_date.charAt){$('#saving_date').text('no data');} else {
            $('#saving_date').text(saving_date);
            var value="$iso3"+saving_date;
            var saving=json["NY.GNS.ICTR.ZS"][value] ;
            if(saving.charAt){$('#saving').text('no data');}else{$('#saving').html('<b>'+saving_date + '</b><br/>'+ saving.toPrecision(3)+' %');}
        }
    //year minus 1
     if(saving_date.charAt){$('#saving_date').text('no data');} else {
         var saving_date_m1= (json["NY.GNS.ICTR.ZS"]["YearMax"]) -1;
        if(saving_date_m1.charAt){$('#saving_date_m1').text('no data');} else {
            $('#saving_date_m1').text(saving_date_m1);
            var value="$iso3"+saving_date_m1;
            var saving_m1=json["NY.GNS.ICTR.ZS"][value] ;
            if(saving_m1.charAt){$('#saving_m1').text('no data');}else{$('#saving_m1').html('<b>'+saving_date_m1 + '</b><br/>'+ saving_m1.toPrecision(3)+' %');}
        }
    }
    
    //year minus 2
    if(saving_date.charAt){$('#saving_date').text('no data');} else {
        var saving_date_m2= (json["NY.GNS.ICTR.ZS"]["YearMax"]) -2;
        if(saving_date_m2.charAt){$('#saving_date_m2').text('no data');} else {
            $('#saving_date_m2').text(saving_date_m2);
            var value="$iso3"+saving_date_m2;
            var saving_m2=json["NY.GNS.ICTR.ZS"][value] ;
            if(saving_m2.charAt){$('#saving_m2').text('no data');}else{$('#saving_m2').html('<b>'+saving_date_m2 + '</b><br/>'+ saving_m2.toPrecision(3)+' %');}
        }
    }
    
    //year minus 3
    if(saving_date.charAt){$('#saving_date').text('no data');} else {
        var saving_date_m3= (json["NY.GNS.ICTR.ZS"]["YearMax"]) -3;
        if(saving_date_m3.charAt){$('#saving_date_m3').text('no data');} else {
            $('#saving_date_m3').text(saving_date_m3);
            var value="$iso3"+saving_date_m3;
            var saving_m3=json["NY.GNS.ICTR.ZS"][value] ;
            if(saving_m3.charAt){$('#saving_m3').text('no data');}else{$('#saving_m3').html('<b>'+saving_date_m3 + '</b><br/>'+ saving_m3.toPrecision(3)+' %');}
        }
    }
    
    //year minus 4
    if(saving_date.charAt){$('#saving_date').text('no data');} else {
        var saving_date_m4= (json["NY.GNS.ICTR.ZS"]["YearMax"]) -4;
        if(saving_date_m4.charAt){$('#saving_date_m4').text('no data');} else {
            $('#saving_date_m4').text(saving_date_m4);
            var value="$iso3"+saving_date_m4;
            var saving_m4=json["NY.GNS.ICTR.ZS"][value] ;
            if(saving_m4.charAt){$('#saving_m4').text('no data');}else{$('#saving_m4').html('<b>'+saving_date_m4 + '</b><br/>'+ saving_m4.toPrecision(3)+' %');}
        }
    }
    
   //=============================================================================
    //consumer price index = FP.CPI.TOTL - 100
        var price_date= json["FP.CPI.TOTL"]["YearMax"] ;
        if(price_date.charAt){$('#price_date').text('no data');} else {
            $('#price_date').text(price_date); 
            var value="$iso3"+price_date;
            var price=json["FP.CPI.TOTL"][value]- 100 ;
            if(price.charAt){$('#price').text('no data');}else{$('#price').html('<b>'+price_date + '</b><br/>'+ price.toPrecision(3)+' %');}
        }
    //year minus 1
    if(price_date.charAt){$('#price_date').text('no data');} else {
        var price_date_m1= (json["FP.CPI.TOTL"]["YearMax"]) -1;
        if(price_date_m1.charAt){$('#price_date_m1').text('no data');} else {
            $('#price_date_m1').text(price_date_m1);
            var value="$iso3"+price_date_m1;
            var price_m1=json["FP.CPI.TOTL"][value]- 100 ;
            if(price_m1.charAt){$('#price_m1').text('no data');}else{$('#price_m1').html('<b>'+price_date_m1 + '</b><br/>'+ price_m1.toPrecision(3)+' %');}
        }
    }
    //year minus 2
    if(price_date.charAt){$('#price_date').text('no data');} else {
        var price_date_m2= (json["FP.CPI.TOTL"]["YearMax"]) -2;
        if(price_date_m2.charAt){$('#price_date_m2').text('no data');} else {
            $('#price_date_m2').text(price_date_m2);
            var value="$iso3"+price_date_m2;
            var price_m2=json["FP.CPI.TOTL"][value]- 100 ;
            if(price_m2.charAt){$('#price_m2').text('no data');}else{$('#price_m2').html('<b>'+price_date_m2 + '</b><br/>'+ price_m2.toPrecision(3)+' %');}
        }
    }
    //year minus 3
    if(price_date.charAt){$('#price_date').text('no data');} else {
        var price_date_m3= (json["FP.CPI.TOTL"]["YearMax"]) -3;
        if(price_date_m3.charAt){$('#price_date_m3').text('no data');} else {
            $('#price_date_m3').text(price_date_m3);
            var value="$iso3"+price_date_m3;
            var price_m3=json["FP.CPI.TOTL"][value]- 100 ;
            if(price_m3.charAt){$('#price_m3').text('no data');}else{$('#price_m3').html('<b>'+price_date_m3 + '</b><br/>'+ price_m3.toPrecision(3)+' %');}
        }
    }
    //year minus 4
     if(price_date.charAt){$('#price_date').text('no data');} else {
        var price_date_m4= (json["FP.CPI.TOTL"]["YearMax"]) -4;
        if(price_date_m4.charAt){$('#price_date_m4').text('no data');} else {
            $('#price_date_m4').text(price_date_m4);
            var value="$iso3"+price_date_m4;
            var price_m4=json["FP.CPI.TOTL"][value]- 100 ;
            if(price_m4.charAt){$('#price_m4').text('no data');}else{$('#price_m4').html('<b>'+price_date_m4 + '</b><br/>'+ price_m4.toPrecision(3)+' %');}
        }
    }




    //=============================================================================
    // Exports of goods and services (annual % growth) = NE.EXP.GNFS.KD.ZG
        var Export_date= json["NE.EXP.GNFS.KD.ZG"]["YearMax"] ;
        if(Export_date.charAt){$('#Export_date').text('no data');} else {
            $('#Export_date').text(Export_date); 
            var value="$iso3"+Export_date;
            var Export=json["NE.EXP.GNFS.KD.ZG"][value] ;
            if(Export.charAt){$('#Export').text('no data');}else{$('#Export').html('<b>'+Export_date + '</b><br/>'+ Export.toPrecision(3)+' %');}
        }
    
    //year minus 1
    if(Export_date.charAt){$('#Export_date').text('no data');} else {
        var Export_date_m1= (json["NE.EXP.GNFS.KD.ZG"]["YearMax"]) -1;
        if(Export_date_m1.charAt){$('#Export_date_m1').text('no data');} else {
            $('#Export_date_m1').text(Export_date_m1);
            var value="$iso3"+Export_date_m1;
            var Export_m1=json["NE.EXP.GNFS.KD.ZG"][value] ;
            if(Export_m1.charAt){$('#Export_m1').text('no data');}else{$('#Export_m1').html('<b>'+Export_date_m1 + '</b><br/>'+ Export_m1.toPrecision(3)+' %');}
        }
    }
    
    //year minus 2
    if(Export_date.charAt){$('#Export_date').text('no data');} else {
        var Export_date_m2= (json["NE.EXP.GNFS.KD.ZG"]["YearMax"]) -2;
        if(Export_date_m2.charAt){$('#Export_date_m2').text('no data');} else {
            $('#Export_date_m2').text(Export_date_m2);
            var value="$iso3"+Export_date_m2;
            var Export_m2=json["NE.EXP.GNFS.KD.ZG"][value] ;
            if(Export_m2.charAt){$('#Export_m2').text('no data');}else{$('#Export_m2').html('<b>'+Export_date_m2 + '</b><br/>'+ Export_m2.toPrecision(3)+' %');}
        }
    }
    
    //year minus 3
    if(Export_date.charAt){$('#Export_date').text('no data');} else {
        var Export_date_m3= (json["NE.EXP.GNFS.KD.ZG"]["YearMax"]) -3;
        if(Export_date_m3.charAt){$('#Export_date_m3').text('no data');} else {
            $('#Export_date_m3').text(Export_date_m3);
            var value="$iso3"+Export_date_m3;
            var Export_m3=json["NE.EXP.GNFS.KD.ZG"][value] ;
            if(Export_m3.charAt){$('#Export_m3').text('no data');}else{$('#Export_m3').html('<b>'+Export_date_m3 + '</b><br/>'+ Export_m3.toPrecision(3)+' %');}
        }
    }
    
    //year minus 4
    if(Export_date.charAt){$('#Export_date').text('no data');} else {
        var Export_date_m4= (json["NE.EXP.GNFS.KD.ZG"]["YearMax"]) -4;
        if(Export_date_m4.charAt){$('#Export_date_m4').text('no data');} else {
            $('#Export_date_m4').text(Export_date_m4);
            var value="$iso3"+Export_date_m4;
            var Export_m4=json["NE.EXP.GNFS.KD.ZG"][value] ;
            if(Export_m4.charAt){$('#Export_m4').text('no data');}else{$('#Export_m4').html('<b>'+Export_date_m4 + '</b><br/>'+ Export_m4.toPrecision(3)+' %');}
        }
    }
    
    //=============================================================================
    // Current account balance (% of GDP) = BN.CAB.XOKA.GD.ZS
        var balance_date= json["BN.CAB.XOKA.GD.ZS"]["YearMax"] ;
        if(balance_date.charAt){$('#balance_date').text('no data');} else {
            $('#balance_date').text(balance_date); 
            var value="$iso3"+balance_date;
            var balance=json["BN.CAB.XOKA.GD.ZS"][value] ;
            if(balance.charAt){$('#balance').text('no data');}else{$('#balance').html('<b>'+balance_date + '</b><br/>'+ balance.toPrecision(3)+' %');}
        }
    //year minus 1
      if(balance_date.charAt){$('#balance_date').text('no data');} else {
        var balance_date_m1= (json["BN.CAB.XOKA.GD.ZS"]["YearMax"]) -1;
        if(balance_date_m1.charAt){$('#balance_date_m1').text('no data');} else {
            $('#balance_date_m1').text(balance_date_m1);
            var value="$iso3"+balance_date_m1;
            var balance_m1=json["BN.CAB.XOKA.GD.ZS"][value] ;
            if(balance_m1.charAt){$('#balance_m1').text('no data');}else{$('#balance_m1').html('<b>'+balance_date_m1 + '</b><br/>'+ balance_m1.toPrecision(3)+' %');}
        }
    }
    //year minus 2
    if(balance_date.charAt){$('#balance_date').text('no data');} else {
        var balance_date_m2= (json["BN.CAB.XOKA.GD.ZS"]["YearMax"]) -2;
        if(balance_date_m2.charAt){$('#balance_date_m2').text('no data');} else {
            $('#balance_date_m2').text(balance_date_m2);
            var value="$iso3"+balance_date_m2;
            var balance_m2=json["BN.CAB.XOKA.GD.ZS"][value] ;
            if(balance_m2.charAt){$('#balance_m2').text('no data');}else{$('#balance_m2').html('<b>'+balance_date_m2 + '</b><br/>'+ balance_m2.toPrecision(3)+' %');}
        }
    //year minus 3
        var balance_date_m3= (json["BN.CAB.XOKA.GD.ZS"]["YearMax"]) -3;
        if(balance_date_m3.charAt){$('#balance_date_m3').text('no data');} else {
            $('#balance_date_m3').text(balance_date_m3);
            var value="$iso3"+balance_date_m3;
            var balance_m3=json["BN.CAB.XOKA.GD.ZS"][value] ;
            if(balance_m3.charAt){$('#balance_m3').text('no data');}else{$('#balance_m3').html('<b>'+balance_date_m3 + '</b><br/>'+ balance_m3.toPrecision(3)+' %');}
        }
    }
    //year minus 4
    if(balance_date.charAt){$('#balance_date').text('no data');} else {
        var balance_date_m4= (json["BN.CAB.XOKA.GD.ZS"]["YearMax"]) -4;
        if(balance_date_m4.charAt){$('#balance_date_m4').text('no data');} else {
            $('#balance_date_m4').text(balance_date_m4);
            var value="$iso3"+balance_date_m4;
            var balance_m4=json["BN.CAB.XOKA.GD.ZS"][value] ;
            if(balance_m4.charAt){$('#balance_m4').text('no data');}else{$('#balance_m4').html('<b>'+balance_date_m4 + '</b><br/>'+ balance_m4.toPrecision(3)+' %');}
        }
    }
    //=============================================================================
    //Cash surplus/deficit (% of GDP) = GC.BAL.CASH.GD.ZS

        // missing
    
    //=============================================================================
    //Total reserves in months of imports= FI.RES.TOTL.MO
        var reserve_date= json["FI.RES.TOTL.MO"]["YearMax"] ;
        if(reserve_date.charAt){$('#reserve_date').text('no data');} else {
            $('#reserve_date').text(reserve_date); 
            var value="$iso3"+reserve_date;
            var reserve=json["FI.RES.TOTL.MO"][value] ;
            if(reserve.charAt){$('#reserve').text('no data');}else{$('#reserve').html('<b>'+reserve_date + '</b><br/>'+ reserve.toPrecision(3));}
        }
    //year minus 1
    if(reserve_date.charAt){$('#reserve_date').text('no data');} else {
        var reserve_date_m1= (json["FI.RES.TOTL.MO"]["YearMax"]) -1;
        if(reserve_date_m1.charAt){$('#reserve_date_m1').text('no data');} else {
            $('#reserve_date_m1').text(reserve_date_m1);
            var value="$iso3"+reserve_date_m1;
            var reserve_m1=json["FI.RES.TOTL.MO"][value] ;
            if(reserve_m1.charAt){$('#reserve_m1').text('no data');}else{$('#reserve_m1').html('<b>'+reserve_date_m1 + '</b><br/>'+ reserve_m1.toPrecision(3));}
        }
    }
    //year minus 2
    if(reserve_date.charAt){$('#reserve_date').text('no data');} else {
        var reserve_date_m2= (json["FI.RES.TOTL.MO"]["YearMax"]) -2;
        if(reserve_date_m2.charAt){$('#reserve_date_m2').text('no data');} else {
            $('#reserve_date_m2').text(reserve_date_m2);
            var value="$iso3"+reserve_date_m2;
            var reserve_m2=json["FI.RES.TOTL.MO"][value] ;
            if(reserve_m2.charAt){$('#reserve_m2').text('no data');}else{$('#reserve_m2').html('<b>'+reserve_date_m2 + '</b><br/>'+ reserve_m2.toPrecision(3));}
        }
    }
    //year minus 3
    if(reserve_date.charAt){$('#reserve_date').text('no data');} else {
        var reserve_date_m3= (json["FI.RES.TOTL.MO"]["YearMax"]) -3;
        if(reserve_date_m3.charAt){$('#reserve_date_m3').text('no data');} else {
            $('#reserve_date_m3').text(reserve_date_m3);
            var value="$iso3"+reserve_date_m3;
            var reserve_m3=json["FI.RES.TOTL.MO"][value] ;
            if(reserve_m3.charAt){$('#reserve_m3').text('no data');}else{$('#reserve_m3').html('<b>'+reserve_date_m3 + '</b><br/>'+ reserve_m3.toPrecision(3));}
        }
    }    
    //year minus 4
    if(reserve_date.charAt){$('#reserve_date').text('no data');} else {
        var reserve_date_m4= (json["FI.RES.TOTL.MO"]["YearMax"]) -4;
        if(reserve_date_m4.charAt){$('#reserve_date_m4').text('no data');} else {
            $('#reserve_date_m4').text(reserve_date_m4);
            var value="$iso3"+reserve_date_m4;
            var reserve_m4=json["FI.RES.TOTL.MO"][value] ;
            if(reserve_m4.charAt){$('#reserve_m4').text('no data');}else{$('#reserve_m4').html('<b>'+reserve_date_m4 + '</b><br/>'+ reserve_m4.toPrecision(3));}
        }
    }
  

  
    //=============================================================================
    //Official exchange rate (LCU $iso3 US$, $iso3iod average)= PA.NUS.FCRF
        var exchange_rate_date= json["PA.NUS.FCRF"]["YearMax"] ;
        if(exchange_rate_date.charAt){$('#exchange_rate_date').text('no data');} else {
            $('#exchange_rate_date').text(exchange_rate_date); 
            var value="$iso3"+exchange_rate_date;
            var exchange_rate=json["PA.NUS.FCRF"][value] ;
            if(exchange_rate.charAt){$('#exchange_rate').text('no data');}else{$('#exchange_rate').html('<b>'+exchange_rate_date + '</b><br/>'+ exchange_rate.toPrecision(6));}
        }
    //year minus 1
    if(exchange_rate_date.charAt){$('#exchange_rate_date').text('no data');} else {
        var exchange_rate_date_m1= (json["PA.NUS.FCRF"]["YearMax"]) -1;
        if(exchange_rate_date_m1.charAt){$('#exchange_rate_date_m1').text('no data');} else {
            $('#exchange_rate_date_m1').text(exchange_rate_date_m1);
            var value="$iso3"+exchange_rate_date_m1;
            var exchange_rate_m1=json["PA.NUS.FCRF"][value] ;
            if(exchange_rate_m1.charAt){$('#exchange_rate_m1').text('no data');}else{$('#exchange_rate_m1').html('<b>'+exchange_rate_date_m1 + '</b><br/>'+ exchange_rate_m1.toPrecision(6));}
        }
    }
    //year minus 2
    if(exchange_rate_date.charAt){$('#exchange_rate_date').text('no data');} else {
        var exchange_rate_date_m2= (json["PA.NUS.FCRF"]["YearMax"]) -2;
        if(exchange_rate_date_m2.charAt){$('#exchange_rate_date_m2').text('no data');} else {
            $('#exchange_rate_date_m2').text(exchange_rate_date_m2);
            var value="$iso3"+exchange_rate_date_m2;
            var exchange_rate_m2=json["PA.NUS.FCRF"][value] ;
            if(exchange_rate_m2.charAt){$('#exchange_rate_m2').text('no data');}else{$('#exchange_rate_m2').html('<b>'+exchange_rate_date_m2 + '</b><br/>'+ exchange_rate_m2.toPrecision(6));}
        }
    }
    //year minus 3
    if(exchange_rate_date.charAt){$('#exchange_rate_date').text('no data');} else {
        var exchange_rate_date_m3= (json["PA.NUS.FCRF"]["YearMax"]) -3;
        if(exchange_rate_date_m3.charAt){$('#exchange_rate_date_m3').text('no data');} else {
            $('#exchange_rate_date_m3').text(exchange_rate_date_m3);
            var value="$iso3"+exchange_rate_date_m3;
            var exchange_rate_m3=json["PA.NUS.FCRF"][value] ;
            if(exchange_rate_m3.charAt){$('#exchange_rate_m3').text('no data');}else{$('#exchange_rate_m3').html('<b>'+exchange_rate_date_m3 + '</b><br/>'+ exchange_rate_m3.toPrecision(6));}
        }
    }
    //year minus 4
    if(exchange_rate_date.charAt){$('#exchange_rate_date').text('no data');} else {
        var exchange_rate_date_m4= (json["PA.NUS.FCRF"]["YearMax"]) -4;
        if(exchange_rate_date_m4.charAt){$('#exchange_rate_date_m4').text('no data');} else {
            $('#exchange_rate_date_m4').text(exchange_rate_date_m4);
            var value="$iso3"+exchange_rate_date_m4;
            var exchange_rate_m4=json["PA.NUS.FCRF"][value] ;
            if(exchange_rate_m4.charAt){$('#exchange_rate_m4').text('no data');}else{$('#exchange_rate_m4').html('<b>'+exchange_rate_date_m4 + '</b><br/>'+ exchange_rate_m4.toPrecision(5));}
        }
    }



    //=============================================================================
    //Real effective exchange rate index (2010 = 100)= PX.REX.REER
        var real_exchge_date= json["PX.REX.REER"]["YearMax"] ;
        if(real_exchge_date.charAt){$('#real_exchge_date').text('no data');} else {
            $('#real_exchge_date').text(real_exchge_date); 
            var value="$iso3"+real_exchge_date;
            var real_exchge=(json["PX.REX.REER"][value]) -100 ;
            if(real_exchge.charAt){$('#real_exchge').text('no data');}else{$('#real_exchge').html('<b>'+real_exchge_date + '</b><br/>'+ real_exchge.toPrecision(3)+' %');}
        }
    //year minus 1
    if(real_exchge_date.charAt){$('#real_exchge_date').text('no data');} else {
        var real_exchge_date_m1= (json["PX.REX.REER"]["YearMax"]) -1;
        if(real_exchge_date_m1.charAt){$('#real_exchge_date_m1').text('no data');} else {
            $('#real_exchge_date_m1').text(real_exchge_date_m1);
            var value="$iso3"+real_exchge_date_m1;
            var real_exchge_m1=(json["PX.REX.REER"][value]) -100  ;
            if(real_exchge_m1.charAt){$('#real_exchge_m1').text('no data');}else{$('#real_exchge_m1').html('<b>'+real_exchge_date_m1 + '</b><br/>'+ real_exchge_m1.toPrecision(3)+' %');}
        }
    }
    //year minus 2
    if(real_exchge_date.charAt){$('#real_exchge_date').text('no data');} else {
        var real_exchge_date_m2= (json["PX.REX.REER"]["YearMax"]) -2;
        if(real_exchge_date_m2.charAt){$('#real_exchge_date_m2').text('no data');} else {
            $('#real_exchge_date_m2').text(real_exchge_date_m2);
            var value="$iso3"+real_exchge_date_m2;
            var real_exchge_m2=(json["PX.REX.REER"][value]) -100  ;
            if(real_exchge_m2.charAt){$('#real_exchge_m2').text('no data');}else{$('#real_exchge_m2').html('<b>'+real_exchge_date_m2 + '</b><br/>'+ real_exchge_m2.toPrecision(3)+' %');}
        }
    }
    //year minus 3
    if(real_exchge_date.charAt){$('#real_exchge_date').text('no data');} else {
        var real_exchge_date_m3= (json["PX.REX.REER"]["YearMax"]) -3;
        if(real_exchge_date_m3.charAt){$('#real_exchge_date_m3').text('no data');} else {
            $('#real_exchge_date_m3').text(real_exchge_date_m3);
            var value="$iso3"+real_exchge_date_m3;
            var real_exchge_m3=(json["PX.REX.REER"][value]) -100  ;
            if(real_exchge_m3.charAt){$('#real_exchge_m3').text('no data');}else{$('#real_exchge_m3').html('<b>'+real_exchge_date_m3 + '</b><br/>'+ real_exchge_m3.toPrecision(3)+' %');}
        }
    }
    //year minus 4
    if(real_exchge_date.charAt){$('#real_exchge_date').text('no data');} else {
        var real_exchge_date_m4= (json["PX.REX.REER"]["YearMax"]) -4;
        if(real_exchge_date_m4.charAt){$('#real_exchge_date_m4').text('no data');} else {
            $('#real_exchge_date_m4').text(real_exchge_date_m4);
            var value="$iso3"+real_exchge_date_m4;
            var real_exchge_m4=(json["PX.REX.REER"][value]) -100  ;
            if(real_exchge_m4.charAt){$('#real_exchge_m4').text('no data');}else{$('#real_exchge_m4').html('<b>'+real_exchge_date_m4 + '</b><br/>'+ real_exchge_m4.toPrecision(3)+' %');}
        }
    }


//=============================================================================
    //Total debt service (% of GNI)=DT.TDS.DECT.GN.ZS
        var debt_serv_date= json["DT.TDS.DECT.GN.ZS"]["YearMax"] ;
        if(debt_serv_date.charAt){$('#debt_serv_date').text('no data');} else {
            $('#debt_serv_date').text(debt_serv_date); 
            var value="$iso3"+debt_serv_date;
            var debt_serv=json["DT.TDS.DECT.GN.ZS"][value] ;
            if(debt_serv.charAt){$('#debt_serv').text('no data');}else{$('#debt_serv').html('<b>'+debt_serv_date + '</b><br/>'+ debt_serv.toPrecision(3)+' %');}
        }
    //year minus 1
    if(debt_serv_date.charAt){$('#debt_serv_date').text('no data');} else {
        var debt_serv_date_m1= (json["DT.TDS.DECT.GN.ZS"]["YearMax"]) -1;
        if(debt_serv_date_m1.charAt){$('#debt_serv_date_m1').text('no data');} else {
            $('#debt_serv_date_m1').text(debt_serv_date_m1);
            var value="$iso3"+debt_serv_date_m1;
            var debt_serv_m1=json["DT.TDS.DECT.GN.ZS"][value] ;
            if(debt_serv_m1.charAt){$('#debt_serv_m1').text('no data');}else{$('#debt_serv_m1').html('<b>'+debt_serv_date_m1 + '</b><br/>'+ debt_serv_m1.toPrecision(3)+' %');}
        }
    }
    //year minus 2
    if(debt_serv_date.charAt){$('#debt_serv_date').text('no data');} else {
        var debt_serv_date_m2= (json["DT.TDS.DECT.GN.ZS"]["YearMax"]) -2;
        if(debt_serv_date_m2.charAt){$('#debt_serv_date_m2').text('no data');} else {
            $('#debt_serv_date_m2').text(debt_serv_date_m2);
            var value="$iso3"+debt_serv_date_m2;
            var debt_serv_m2=json["DT.TDS.DECT.GN.ZS"][value] ;
            if(debt_serv_m2.charAt){$('#debt_serv_m2').text('no data');}else{$('#debt_serv_m2').html('<b>'+debt_serv_date_m2 + '</b><br/>'+ debt_serv_m2.toPrecision(3)+' %');}
        }
    }
    //year minus 3
    if(debt_serv_date.charAt){$('#debt_serv_date').text('no data');} else { 
         var debt_serv_date_m3= (json["DT.TDS.DECT.GN.ZS"]["YearMax"]) -3;
            if(debt_serv_date_m3.charAt){$('#debt_serv_date_m3').text('no data');} else {
            $('#debt_serv_date_m3').text(debt_serv_date_m3);
            var value="$iso3"+debt_serv_date_m3;
            var debt_serv_m3=json["DT.TDS.DECT.GN.ZS"][value] ;
            if(debt_serv_m3.charAt){$('#debt_serv_m3').text('no data');}else{$('#debt_serv_m3').html('<b>'+debt_serv_date_m3 + '</b><br/>'+ debt_serv_m3.toPrecision(3)+' %');}
        }
    }
    //year minus 4
    if(debt_serv_date.charAt){$('#debt_serv_date').text('no data');} else {
        var debt_serv_date_m4= (json["DT.TDS.DECT.GN.ZS"]["YearMax"]) -4;
        if(debt_serv_date_m4.charAt){$('#debt_serv_date_m4').text('no data');} else {
            $('#debt_serv_date_m4').text(debt_serv_date_m4);
            var value="$iso3"+debt_serv_date_m4;
            var debt_serv_m4=json["DT.TDS.DECT.GN.ZS"][value] ;
            if(debt_serv_m4.charAt){$('#debt_serv_m4').text('no data');}else{$('#debt_serv_m4').html('<b>'+debt_serv_date_m4 + '</b><br/>'+ debt_serv_m4.toPrecision(3)+' %');}
        }
    }
    //=============================================================================
    //=============================================================================
    //Interest payments (% of revenue)= GC.XPN.INTP.RV.ZS
        var interest_payment_date= json["GC.XPN.INTP.RV.ZS"]["YearMax"] ;
        if(interest_payment_date.charAt){$('#interest_payment_date').text('no data');} else {
            $('#interest_payment_date').text(interest_payment_date); 
            var value="$iso3"+interest_payment_date;
            var interest_payment=json["GC.XPN.INTP.RV.ZS"][value] ;
            if(interest_payment.charAt){$('#interest_payment').text('no data');}else{$('#interest_payment').html('<b>'+interest_payment_date + '</b><br/>'+ interest_payment.toPrecision(3)+' %');}
        }
    //year minus 1
    if(interest_payment_date.charAt){$('#interest_payment_date').text('no data');} else {
        var interest_payment_date_m1= (json["GC.XPN.INTP.RV.ZS"]["YearMax"]) -1;
        if(interest_payment_date_m1.charAt){$('#interest_payment_date_m1').text('no data');} else {
            $('#interest_payment_date_m1').text(interest_payment_date_m1);
            var value="$iso3"+interest_payment_date_m1;
            var interest_payment_m1=json["GC.XPN.INTP.RV.ZS"][value] ;
            if(interest_payment_m1.charAt){$('#interest_payment_m1').text('no data');}else{$('#interest_payment_m1').html('<b>'+interest_payment_date_m1 + '</b><br/>'+ interest_payment_m1.toPrecision(3)+' %');}
        }
    }
    //year minus 2
    if(interest_payment_date.charAt){$('#interest_payment_date').text('no data');} else {
        var interest_payment_date_m2= (json["GC.XPN.INTP.RV.ZS"]["YearMax"]) -2;
        if(interest_payment_date_m2.charAt){$('#interest_payment_date_m2').text('no data');} else {
            $('#interest_payment_date_m2').text(interest_payment_date_m2);
            var value="$iso3"+interest_payment_date_m2;
            var interest_payment_m2=json["GC.XPN.INTP.RV.ZS"][value] ;
            if(interest_payment_m2.charAt){$('#interest_payment_m2').text('no data');}else{$('#interest_payment_m2').html('<b>'+interest_payment_date_m2 + '</b><br/>'+ interest_payment_m2.toPrecision(3)+' %');}
        }
    }
    //year minus 3
    if(interest_payment_date.charAt){$('#interest_payment_date').text('no data');} else {
        var interest_payment_date_m3= (json["GC.XPN.INTP.RV.ZS"]["YearMax"]) -3;
        if(interest_payment_date_m3.charAt){$('#interest_payment_date_m3').text('no data');} else {
            $('#interest_payment_date_m3').text(interest_payment_date_m3);
            var value="$iso3"+interest_payment_date_m3;
            var interest_payment_m3=json["GC.XPN.INTP.RV.ZS"][value] ;
            if(interest_payment_m3.charAt){$('#interest_payment_m3').text('no data');}else{$('#interest_payment_m3').html('<b>'+interest_payment_date_m3 + '</b><br/>'+ interest_payment_m3.toPrecision(3)+' %');}
        }
    }
    //year minus 4
    if(interest_payment_date.charAt){$('#interest_payment_date').text('no data');} else {
        var interest_payment_date_m4= (json["GC.XPN.INTP.RV.ZS"]["YearMax"]) -4;
        if(interest_payment_date_m4.charAt){$('#interest_payment_date_m4').text('no data');} else {
            $('#interest_payment_date_m4').text(interest_payment_date_m4);
            var value="$iso3"+interest_payment_date_m4;
            var interest_payment_m4=json["GC.XPN.INTP.RV.ZS"][value] ;
            if(interest_payment_m4.charAt){$('#interest_payment_m4').text('no data');}else{$('#interest_payment_m4').html('<b>'+interest_payment_date_m4 + '</b><br/>'+ interest_payment_m4.toPrecision(3)+' %');}
        }
    }


//=============================================================================
    //Revenue, excluding grants (% of GDP) = GC.REV.XGRT.GD.ZS
        var revenue_date= json["GC.REV.XGRT.GD.ZS"]["YearMax"] ;
        if(revenue_date.charAt){$('#revenue_date').text('no data');} else {
            $('#revenue_date').text(revenue_date); 
            var value="$iso3"+revenue_date;
            var revenue=json["GC.REV.XGRT.GD.ZS"][value] ;
            if(revenue.charAt){$('#revenue').text('no data');}else{$('#revenue').html('<b>'+revenue_date + '</b><br/>'+ revenue.toPrecision(3)+' %');}
        }
    //year minus 1
    if(revenue_date.charAt){$('#revenue_date').text('no data');} else {
        var revenue_date_m1= (json["GC.REV.XGRT.GD.ZS"]["YearMax"]) -1;
        if(revenue_date_m1.charAt){$('#revenue_date_m1').text('no data');} else {        
            $('#revenue_date_m1').text(revenue_date_m1);
            var value="$iso3"+revenue_date_m1;
            var revenue_m1=json["GC.REV.XGRT.GD.ZS"][value] ;
            if(revenue_m1.charAt){$('#revenue_m1').text('no data');}else{$('#revenue_m1').html('<b>'+revenue_date_m1 + '</b><br/>'+ revenue_m1.toPrecision(3)+' %');}
        }
    }
    //year minus 2
    if(revenue_date.charAt){$('#revenue_date').text('no data');} else {
        var revenue_date_m2= (json["GC.REV.XGRT.GD.ZS"]["YearMax"]) -2;
        if(revenue_date_m2.charAt){$('#revenue_date_m2').text('no data');} else {
            $('#revenue_date_m2').text(revenue_date_m2);
            var value="$iso3"+revenue_date_m2;
            var revenue_m2=json["GC.REV.XGRT.GD.ZS"][value] ;
            if(revenue_m2.charAt){$('#revenue_m2').text('no data');}else{$('#revenue_m2').html('<b>'+revenue_date_m2 + '</b><br/>'+ revenue_m2.toPrecision(3)+' %');}
        }
    }
    //year minus 3
    if(revenue_date.charAt){$('#revenue_date').text('no data');} else {
        var revenue_date_m3= (json["GC.REV.XGRT.GD.ZS"]["YearMax"]) -3;
        if(revenue_date_m3.charAt){$('#revenue_date_m3').text('no data');} else {
            $('#revenue_date_m3').text(revenue_date_m3);
            var value="$iso3"+revenue_date_m3;
            var revenue_m3=json["GC.REV.XGRT.GD.ZS"][value] ;
            if(revenue_m3.charAt){$('#revenue_m3').text('no data');}else{$('#revenue_m3').html('<b>'+revenue_date_m3 + '</b><br/>'+ revenue_m3.toPrecision(3)+' %');}
        }
    }
    //year minus 4
     if(revenue_date.charAt){$('#revenue_date').text('no data');} else {
         var revenue_date_m4= (json["GC.REV.XGRT.GD.ZS"]["YearMax"]) -4;
        if(revenue_date_m4.charAt){$('#revenue_date_m4').text('no data');} else {
            $('#revenue_date_m4').text(revenue_date_m4);
            var value="$iso3"+revenue_date_m4;
            var revenue_m4=json["GC.REV.XGRT.GD.ZS"][value] ;
            if(revenue_m4.charAt){$('#revenue_m4').text('no data');}else{$('#revenue_m4').html('<b>'+revenue_date_m4 + '</b><br/>'+ revenue_m4.toPrecision(3)+' %');}
        }
    }
       
    //=============================================================================
  
 
   //Real interest rate (%) = FR.INR.RINR
        var real_interest_rate_date= json["FR.INR.RINR"]["YearMax"] ;
        if(real_interest_rate_date.charAt){$('#real_interest_rate_date').text('no data');} else {
            $('#real_interest_rate_date').text(real_interest_rate_date); 
            var value="$iso3"+real_interest_rate_date;
            var real_interest_rate=json["FR.INR.RINR"][value] ;
            if(real_interest_rate.charAt){$('#real_interest_rate').text('no data');}else{$('#real_interest_rate').html('<b>'+real_interest_rate_date + '</b><br/>'+ real_interest_rate.toPrecision(3)+' %');}
        }
    //year minus 1
    if(real_interest_rate_date.charAt){$('#real_interest_rate_date').text('no data');} else {
        var real_interest_rate_date_m1= (json["FR.INR.RINR"]["YearMax"]) -1;
        if(real_interest_rate_date_m1.charAt){$('#real_interest_rate_date_m1').text('no data');} else {
            $('#real_interest_rate_date_m1').text(real_interest_rate_date_m1);
            var value="$iso3"+real_interest_rate_date_m1;
            var real_interest_rate_m1=json["FR.INR.RINR"][value] ;
            if(real_interest_rate_m1.charAt){$('#real_interest_rate_m1').text('no data');}else{$('#real_interest_rate_m1').html('<b>'+real_interest_rate_date_m1 + '</b><br/>'+ real_interest_rate_m1.toPrecision(3)+' %');}
        }
    }
    //year minus 2
    if(real_interest_rate_date.charAt){$('#real_interest_rate_date').text('no data');} else {
        var real_interest_rate_date_m2= (json["FR.INR.RINR"]["YearMax"]) -2;
        if(real_interest_rate_date_m2.charAt){$('#real_interest_rate_date_m2').text('no data');} else {
            $('#real_interest_rate_date_m2').text(real_interest_rate_date_m2);
            var value="$iso3"+real_interest_rate_date_m2;
            var real_interest_rate_m2=json["FR.INR.RINR"][value] ;
            if(real_interest_rate_m2.charAt){$('#real_interest_rate_m2').text('no data');}else{$('#real_interest_rate_m2').html('<b>'+real_interest_rate_date_m2 + '</b><br/>'+ real_interest_rate_m2.toPrecision(3)+' %');}
        }
    }
    //year minus 3
    if(real_interest_rate_date.charAt){$('#real_interest_rate_date').text('no data');} else {
        var real_interest_rate_date_m3= (json["FR.INR.RINR"]["YearMax"]) -3;
        if(real_interest_rate_date_m3.charAt){$('#real_interest_rate_date_m3').text('no data');} else {
            $('#real_interest_rate_date_m3').text(real_interest_rate_date_m3);
            var value="$iso3"+real_interest_rate_date_m3;
            var real_interest_rate_m3=json["FR.INR.RINR"][value] ;
            if(real_interest_rate_m3.charAt){$('#real_interest_rate_m3').text('no data');}else{$('#real_interest_rate_m3').html('<b>'+real_interest_rate_date_m3 + '</b><br/>'+ real_interest_rate_m3.toPrecision(3)+' %');}
        }
    }
    //year minus 4
    if(real_interest_rate_date.charAt){$('#real_interest_rate_date').text('no data');} else {
        var real_interest_rate_date_m4= (json["FR.INR.RINR"]["YearMax"]) -4;
        if(real_interest_rate_date_m4.charAt){$('#real_interest_rate_date_m4').text('no data');} else {
            $('#real_interest_rate_date_m4').text(real_interest_rate_date_m4);
            var value="$iso3"+real_interest_rate_date_m4;
            var real_interest_rate_m4=json["FR.INR.RINR"][value] ;
            if(real_interest_rate_m4.charAt){$('#real_interest_rate_m4').text('no data');}else{$('#real_interest_rate_m4').html('<b>'+real_interest_rate_date_m4 + '</b><br/>'+ real_interest_rate_m4.toPrecision(3)+' %');}
            }
        }
 
    //=============================================================================
    //Domestic credit to private sector (% of GDP)= FS.AST.PRVT.GD.ZS
        var credit_ps_date= json["FS.AST.PRVT.GD.ZS"]["YearMax"] ;
        if(credit_ps_date.charAt){$('#credit_ps_date').text('no data');} else {
            $('#credit_ps_date').text(credit_ps_date); 
            var value="$iso3"+credit_ps_date;
            var credit_ps=json["FS.AST.PRVT.GD.ZS"][value] ;
            if(credit_ps.charAt){$('#credit_ps').text('no data');}else{$('#credit_ps').html('<b>'+credit_ps_date + '</b><br/>'+ credit_ps.toPrecision(3)+' %');}
        }
    //year minus 1
     if(credit_ps_date.charAt){$('#credit_ps_date').text('no data');} else {
        var credit_ps_date_m1= (json["FS.AST.PRVT.GD.ZS"]["YearMax"]) -1;
        if(credit_ps_date_m1.charAt){$('#credit_ps_date_m1').text('no data');} else {
            $('#credit_ps_date_m1').text(credit_ps_date_m1);
            var value="$iso3"+credit_ps_date_m1;
            var credit_ps_m1=json["FS.AST.PRVT.GD.ZS"][value] ;
            if(credit_ps_m1.charAt){$('#credit_ps_m1').text('no data');}else{$('#credit_ps_m1').html('<b>'+credit_ps_date_m1 + '</b><br/>'+ credit_ps_m1.toPrecision(3)+' %');}
        }
    }
    //year minus 2
    if(credit_ps_date.charAt){$('#credit_ps_date').text('no data');} else {
        var credit_ps_date_m2= (json["FS.AST.PRVT.GD.ZS"]["YearMax"]) -2;
        if(credit_ps_date_m2.charAt){$('#credit_ps_date_m2').text('no data');} else {
            $('#credit_ps_date_m2').text(credit_ps_date_m2);
            var value="$iso3"+credit_ps_date_m2;
            var credit_ps_m2=json["FS.AST.PRVT.GD.ZS"][value] ;
            if(credit_ps_m2.charAt){$('#credit_ps_m2').text('no data');}else{$('#credit_ps_m2').html('<b>'+credit_ps_date_m2 + '</b><br/>'+ credit_ps_m2.toPrecision(3)+' %');}
        }
    }
    //year minus 3
     if(credit_ps_date.charAt){$('#credit_ps_date').text('no data');} else {
        var credit_ps_date_m3= (json["FS.AST.PRVT.GD.ZS"]["YearMax"]) -3;
        if(credit_ps_date_m3.charAt){$('#credit_ps_date_m3').text('no data');} else {
            $('#credit_ps_date_m3').text(credit_ps_date_m3);
            var value="$iso3"+credit_ps_date_m3;
            var credit_ps_m3=json["FS.AST.PRVT.GD.ZS"][value] ;
            if(credit_ps_m3.charAt){$('#credit_ps_m3').text('no data');}else{$('#credit_ps_m3').html('<b>'+credit_ps_date_m3 + '</b><br/>'+ credit_ps_m3.toPrecision(3)+' %');}
        }
    }
    //year minus 4
    if(credit_ps_date.charAt){$('#credit_ps_date').text('no data');} else {
        var credit_ps_date_m4= (json["FS.AST.PRVT.GD.ZS"]["YearMax"]) -4;
        if(credit_ps_date_m4.charAt){$('#credit_ps_date_m4').text('no data');} else {
            $('#credit_ps_date_m4').text(credit_ps_date_m4);
            var value="$iso3"+credit_ps_date_m4;
            var credit_ps_m4=json["FS.AST.PRVT.GD.ZS"][value] ;
            if(credit_ps_m4.charAt){$('#credit_ps_m4').text('no data');}else{$('#credit_ps_m4').html('<b>'+credit_ps_date_m4 + '</b><br/>'+ credit_ps_m4.toPrecision(3)+' %');}
        }
    }
    

    //=============================================================================
    
     //Money and quasi money (M2) as % of GDP=FM.LBL.MQMY.GD.ZS
        var money_date= json["FM.LBL.MQMY.GD.ZS"]["YearMax"] ;
        if(money_date.charAt){$('#money_date').text('no data');} else {
            $('#money_date').text(money_date); 
            var value="$iso3"+money_date;
            var money=json["FM.LBL.MQMY.GD.ZS"][value] ;
            if(money.charAt){$('#money').text('no data');}else{$('#money').html('<b>'+money_date + '</b><br/>'+ money.toPrecision(3)+' %');}
        }
        
    //year minus 1
    if(money_date.charAt){$('#money_date').text('no data');} else {
        var money_date_m1= (json["FM.LBL.MQMY.GD.ZS"]["YearMax"]) -1;
        if(money_date_m1.charAt){$('#money_date_m1').text('no data');} else {
            $('#money_date_m1').text(money_date_m1);
            var value="$iso3"+money_date_m1;
            var money_m1=json["FM.LBL.MQMY.GD.ZS"][value] ;
            if(money_m1.charAt){$('#money_m1').text('no data');}else{$('#money_m1').html('<b>'+money_date_m1 + '</b><br/>'+ money_m1.toPrecision(3)+' %');}
        }
    }
    //year minus 2
    if(money_date.charAt){$('#money_date').text('no data');} else {
        var money_date_m2= (json["FM.LBL.MQMY.GD.ZS"]["YearMax"]) -2;
        if(money_date_m2.charAt){$('#money_date_m2').text('no data');} else {
            $('#money_date_m2').text(money_date_m2);
            var value="$iso3"+money_date_m2;
            var money_m2=json["FM.LBL.MQMY.GD.ZS"][value] ;
            if(money_m2.charAt){$('#money_m2').text('no data');}else{$('#money_m2').html('<b>'+money_date_m2 + '</b><br/>'+ money_m2.toPrecision(3)+' %');}
        }
    }
    //year minus 3
    if(money_date.charAt){$('#money_date').text('no data');} else {
        var money_date_m3= (json["FM.LBL.MQMY.GD.ZS"]["YearMax"]) -3;
        if(money_date_m3.charAt){$('#money_date_m3').text('no data');} else {
            $('#money_date_m3').text(money_date_m3);
            var value="$iso3"+money_date_m3;
            var money_m3=json["FM.LBL.MQMY.GD.ZS"][value] ;
            if(money_m3.charAt){$('#money_m3').text('no data');}else{$('#money_m3').html('<b>'+money_date_m3 + '</b><br/>'+ money_m3.toPrecision(3)+' %');}
        }
    }
    //year minus 4
    if(money_date.charAt){$('#money_date').text('no data');} else {
        var money_date_m4= (json["FM.LBL.MQMY.GD.ZS"]["YearMax"]) -4;
        if(money_date_m4.charAt){$('#money_date_m4').text('no data');} else {
            $('#money_date_m4').text(money_date_m4);
            var value="$iso3"+money_date_m4;
            var money_m4=json["FM.LBL.MQMY.GD.ZS"][value] ;
            if(money_m4.charAt){$('#money_m4').text('no data');}else{$('#money_m4').html('<b>'+money_date_m4 + '</b><br/>'+ money_m4.toPrecision(3)+' %');}
        }
     }
     

        
        }); // end get json
        
    //=============================================================================
    //     IMF WEO ! YearMax = projection
    //=============================================================================
    
    $.getJSON("http://afd.countrydashboards.com/glance/data/WEO_$iso3.json", function (json) {
          
    //=============================================================================
    //General Government Net Lending/Borrowing % of GDP = GGXONLB_NGDP  Solde budgétaire primaire
        var solde_budg_prim_date= json["GGXONLB_NGDP"]["YearMax"] -6;
        if(solde_budg_prim_date.charAt){$('#solde_budg_prim_date').text('no data');} else {
            $('#solde_budg_prim_date').text(solde_budg_prim_date); 
            var value="$iso3"+solde_budg_prim_date;
            var solde_budg_prim=json["GGXONLB_NGDP"][value] ;
            if(solde_budg_prim.charAt){$('#solde_budg_prim').text('no data');}else{$('#solde_budg_prim').html('<b>'+solde_budg_prim_date + '</b><br/>'+ solde_budg_prim.toPrecision(3)+' %');}
        }
    //year minus 1
    if(solde_budg_prim_date.charAt){$('#solde_budg_prim_date').text('no data');} else {
        var solde_budg_prim_date_m1= (json["GGXONLB_NGDP"]["YearMax"]) -7;
        if(solde_budg_prim_date_m1.charAt){$('#solde_budg_prim_date_m1').text('no data');} else {
            $('#solde_budg_prim_date_m1').text(solde_budg_prim_date_m1);
            var value="$iso3"+solde_budg_prim_date_m1;
            var solde_budg_prim_m1=json["GGXONLB_NGDP"][value] ;
            if(solde_budg_prim_m1.charAt){$('#solde_budg_prim_m1').text('no data');}else{$('#solde_budg_prim_m1').html('<b>'+solde_budg_prim_date_m1 + '</b><br/>'+ solde_budg_prim_m1.toPrecision(3)+' %');}
        }
    }
    //year minus 2
    if(solde_budg_prim_date.charAt){$('#solde_budg_prim_date').text('no data');} else {
        var solde_budg_prim_date_m2= (json["GGXONLB_NGDP"]["YearMax"]) -8;
        if(solde_budg_prim_date_m2.charAt){$('#solde_budg_prim_date_m2').text('no data');} else {
            $('#solde_budg_prim_date_m2').text(solde_budg_prim_date_m2);
            var value="$iso3"+solde_budg_prim_date_m2;
            var solde_budg_prim_m2=json["GGXONLB_NGDP"][value] ;
            if(solde_budg_prim_m2.charAt){$('#solde_budg_prim_m2').text('no data');}else{$('#solde_budg_prim_m2').html('<b>'+solde_budg_prim_date_m2 + '</b><br/>'+ solde_budg_prim_m2.toPrecision(3)+' %');}
        }
    }
    //year minus 3
    if(solde_budg_prim_date.charAt){$('#solde_budg_prim_date').text('no data');} else {
        var solde_budg_prim_date_m3= (json["GGXONLB_NGDP"]["YearMax"]) -9;
        if(solde_budg_prim_date_m3.charAt){$('#solde_budg_prim_date_m3').text('no data');} else {
            $('#solde_budg_prim_date_m3').text(solde_budg_prim_date_m3);
            var value="$iso3"+solde_budg_prim_date_m3;
            var solde_budg_prim_m3=json["GGXONLB_NGDP"][value] ;
            if(solde_budg_prim_m3.charAt){$('#solde_budg_prim_m3').text('no data');}else{$('#solde_budg_prim_m3').html('<b>'+solde_budg_prim_date_m3 + '</b><br/>'+ solde_budg_prim_m3.toPrecision(3)+' %');}
        }
    }
    //year minus 4
    if(solde_budg_prim_date.charAt){$('#solde_budg_prim_date').text('no data');} else {
        var solde_budg_prim_date_m4= (json["GGXONLB_NGDP"]["YearMax"]) -10;
        if(solde_budg_prim_date_m4.charAt){$('#solde_budg_prim_date_m4').text('no data');} else {
            $('#solde_budg_prim_date_m4').text(solde_budg_prim_date_m4);
            var value="$iso3"+solde_budg_prim_date_m4;
            var solde_budg_prim_m4=json["GGXONLB_NGDP"][value] ;
            if(solde_budg_prim_m4.charAt){$('#solde_budg_prim_m4').text('no data');}else{$('#solde_budg_prim_m4').html('<b>'+solde_budg_prim_date_m4 + '</b><br/>'+ solde_budg_prim_m4.toPrecision(3)+' %');}
        }
    }
 
 
 //=============================================================================
    //General Government Net Lending/Borrowing % of GDP = GGXCNL_NGDP  Solde budgétaire global
        var solde_budg_glob_date= json["GGXCNL_NGDP"]["YearMax"] -6;
        if(solde_budg_glob_date.charAt){$('#solde_budg_glob_date').text('no data');} else {
            $('#solde_budg_glob_date').text(solde_budg_glob_date); 
            var value="$iso3"+solde_budg_glob_date;
            var solde_budg_glob=json["GGXCNL_NGDP"][value] ;
            if(solde_budg_glob.charAt){$('#solde_budg_glob').text('no data');}else{$('#solde_budg_glob').html('<b>'+solde_budg_glob_date + '</b><br/>'+ solde_budg_glob.toPrecision(3)+' %');}
        }
    //year minus 1
    if(solde_budg_glob_date.charAt){$('#solde_budg_glob_date').text('no data');} else {
        var solde_budg_glob_date_m1= (json["GGXCNL_NGDP"]["YearMax"]) -7;
        if(solde_budg_glob_date_m1.charAt){$('#solde_budg_glob_date_m1').text('no data');} else {
            $('#solde_budg_glob_date_m1').text(solde_budg_glob_date_m1);
            var value="$iso3"+solde_budg_glob_date_m1;
            var solde_budg_glob_m1=json["GGXCNL_NGDP"][value] ;
            if(solde_budg_glob_m1.charAt){$('#solde_budg_glob_m1').text('no data');}else{$('#solde_budg_glob_m1').html('<b>'+solde_budg_glob_date_m1 + '</b><br/>'+ solde_budg_glob_m1.toPrecision(3)+' %');}
        }
    }
    //year minus 2
    if(solde_budg_glob_date.charAt){$('#solde_budg_glob_date').text('no data');} else {
        var solde_budg_glob_date_m2= (json["GGXCNL_NGDP"]["YearMax"]) -8;
        if(solde_budg_glob_date_m2.charAt){$('#solde_budg_glob_date_m2').text('no data');} else {
            $('#solde_budg_glob_date_m2').text(solde_budg_glob_date_m2);
            var value="$iso3"+solde_budg_glob_date_m2;
            var solde_budg_glob_m2=json["GGXCNL_NGDP"][value] ;
            if(solde_budg_glob_m2.charAt){$('#solde_budg_glob_m2').text('no data');}else{$('#solde_budg_glob_m2').html('<b>'+solde_budg_glob_date_m2 + '</b><br/>'+ solde_budg_glob_m2.toPrecision(3)+' %');}
        }
    }
    //year minus 3
    if(solde_budg_glob_date.charAt){$('#solde_budg_glob_date').text('no data');} else {
        var solde_budg_glob_date_m3= (json["GGXCNL_NGDP"]["YearMax"]) -9;
        if(solde_budg_glob_date_m3.charAt){$('#solde_budg_glob_date_m3').text('no data');} else {
            $('#solde_budg_glob_date_m3').text(solde_budg_glob_date_m3);
            var value="$iso3"+solde_budg_glob_date_m3;
            var solde_budg_glob_m3=json["GGXCNL_NGDP"][value] ;
            if(solde_budg_glob_m3.charAt){$('#solde_budg_glob_m3').text('no data');}else{$('#solde_budg_glob_m3').html('<b>'+solde_budg_glob_date_m3 + '</b><br/>'+ solde_budg_glob_m3.toPrecision(3)+' %');}
        }
    }
    //year minus 4
    if(solde_budg_glob_date.charAt){$('#solde_budg_glob_date').text('no data');} else {
        var solde_budg_glob_date_m4= (json["GGXCNL_NGDP"]["YearMax"]) -10;
        if(solde_budg_glob_date_m4.charAt){$('#solde_budg_glob_date_m4').text('no data');} else {
            $('#solde_budg_glob_date_m4').text(solde_budg_glob_date_m4);
            var value="$iso3"+solde_budg_glob_date_m4;
            var solde_budg_glob_m4=json["GGXCNL_NGDP"][value] ;
            if(solde_budg_glob_m4.charAt){$('#solde_budg_glob_m4').text('no data');}else{$('#solde_budg_glob_m4').html('<b>'+solde_budg_glob_date_m4 + '</b><br/>'+ solde_budg_glob_m4.toPrecision(3)+' %');}
        }
    }    
          
         }); // end get json
        
      //=============================================================================
    //     HDR data 
    //=============================================================================
    
    $.getJSON("http://afd.countrydashboards.com/glance/data/HDRdata_$iso3.json", function (json) {
          
    //=============================================================================
   
   //HDI
     var HDI_date= json["v_137506"]["YearMax"];
        if(HDI_date.charAt){$('#HDI_date').text('no data');} else {
            $('#HDI_date').text(HDI_date);
            var value="$iso3"+HDI_date;
            var HDI = json["v_137506"][value];
            // toLocaleString() function allows separating thousands
            if(HDI.charAt){$('#HDI').text('no data');}else{$('#HDI').text(HDI.toLocaleString());}
        }
          
          
         }); // end get json    
    
    
    
    } // end window onload

    </script>


    </head>
    <body>
   <img src='logo.png'><h1><span style="font-family:Trebuchet MS; font-size:29pt;"><font color="#224068">Country at a glance:</span> <font color="#189cdd">
    <object id="country"; style="font-family:Trebuchet MS; font-size:29pt;"></object></h1></font> <br> <br>
    <table style="width:100%;">
        <hr>
    <td style="width:525px">
    <div id="frame">
    
    <div id="dataviz1" class="dataviz">
    <iframe src="http://afd.countrydashboards.com/TimeSerie/TimeSerie_NGDP_RPCH_$iso3.html" frameborder="0" height="100%" width="100%"></iframe>   
    </div>
    
    <div id="dataviz11" class="dataviz">
    <iframe src="http://afd.countrydashboards.com/TimeSerie_2var/TimeSerie_PCPIPCH_&_FM_AST_DOMS_CN_real_gr_$iso3.html" frameborder="0" height="100%" width="100%"></iframe>   
    </div>

    <div id="dataviz2" class="dataviz">
    <iframe src="http://afd.countrydashboards.com/TimeSerie/TimeSerie_FS_AST_PRVT_GD_ZS_$iso3.html" frameborder="0" height="100%" width="100%"></iframe>
    </div>

    <div id="dataviz3" class="dataviz">
    <iframe src="http://afd.countrydashboards.com/TimeSerie_2var/TimeSerie_BCA_NGDPD_&_GGXCNL_NGDP_$iso3.html" frameborder="0" height="100%" width="100%"></iframe>
    </div>

    <div id="dataviz4" class="dataviz">
    <iframe src="http://afd.countrydashboards.com/TimeSerie_2var/TimeSerie_DT_DOD_DECT_GN_ZS_&_GC_DOD_TOTL_GD_ZS_$iso3.html" frameborder="0" height="100%" width="100%"></iframe>
    </div>  

      </div>    
    </td>

    <td>
    <table style="width:950px; height:2100px;">
    <tr><th><h2>Indicateurs structurels <hr></h2></th></tr>
    <tr><th>Indicateurs Démographiques</th><td><i><b>Valeurs</i></td>
    <td><i><b>Années</i></b></td>
      
      </tr>
      <tr>
    <td >Population</td>
    <td id="Pop"></td><td id="Pop_date"></td>
      </tr>

      <tr>
    <td colspan="1">Répartition population par âge (en % de la population totale)</td>
      </tr>

      <tr>
    <td >&nbsp;&nbsp;&nbsp;&nbsp;0 - 14 ans</td>
    <td id="Pop1"></td><td id="Pop1_date"></td>
      </tr>

      <tr>
    <td >&nbsp;&nbsp;&nbsp;&nbsp;15 - 64 ans</td>
    <td id="Pop2"></td><td id="Pop2_date"></td>
      </tr>
      
      <tr>
    <td >&nbsp;&nbsp;&nbsp;&nbsp;64 + ans</td>
    <td id="Pop3"></td><td id="Pop3_date"></td>
      </tr>

    <tr>
    <td >Croissance annuelle moyenne de la population (moy. 4 dernières années dispo)</td>
    <td id="Pop_g"></td><td id="Pop_g_date"></td>
     </tr>

    <tr>
    <td >Croissance annuelle moyenne de la population active (moy. 4 dernières années dispo)</td>
    <td id="Pop_active_g"></td><td id="Pop_active_g_date"></td>
    </tr>

    <tr>
    <td >Population urbaine (% de la population totale)</td>
    <td id="urban_pop"></td><td id="urban_pop_date"></td>
    </tr>
  
    <tr><th>Indicateurs sociaux</th></tr>
    
    <tr>
    <td>PIB par habitant (US$ courants)</td>
    <td id="pib_pc"></td><td id="pib_pc_date"></td>
    </tr>

    <tr>
    <td>PIB par habitant en parité de pouvoir d'achat (2011, int. US$ constants)</td>
    <td id="pib_pcppa"></td><td id="pib_pcppa_date"></td>
    </tr>

    <tr>
    <td>Population en dessous du seuil de pauvreté (% de la population totale)</td>
    <td id="pov"></td><td id="pov_date"></td>
    </tr>

    <tr>
    <td>Espérance de vie à la naissance (années) </td>
    <td id="esp_vie"></td><td id="esp_vie_date"></td>
    </tr>

    <tr>
    <td>Mortalité infantile (pour 1000 naissance) </td>
    <td id="mort"></td> <td id="mort_date"></td>
    </tr>

    <tr>
    <td>Accès à l'eau potable (% de la population)  </td>
    <td id="water" ></td><td id="water_date"></td>
      </tr>

    <tr>
    <td>Analphabétisme (en % de la population de plus de 15 ans) </td>
    <td id="literacy"></td><td id="literacy_date"></td>
    </tr>

    <tr>
    <td>Taux brut de scolarisation primaire</td>
    <td id="school"></td><td id="school_date"></td>
    </tr>

    <tr>
    <td>Taux de chomage (en % de la pop. active) </td>
    <td id="unemployment"></td><td id="unemployment_date"></td>
    </tr>

    <tr>
    <td>Indicateur de Développement Humain</td>
    <td id="HDI"></td><td id="HDI_date"></td>
    </tr>


    <tr><th>Indicateurs économiques</th></tr>
    
    <tr>
    <td colspan="1">Structure de l'économie (% PIB)</td>
    </tr>

    <tr>
    <td >&nbsp;&nbsp;&nbsp;&nbsp;Agriculture</td>
    <td id="share_agri"></td><td id="share_agri_date"></td>
    </tr>

    <tr>
    <td >&nbsp;&nbsp;&nbsp;&nbsp;Industrie</td>
    <td id="share_indust"></td><td id="share_indust_date"></td>
    </tr>

    <tr>
    <td >&nbsp;&nbsp;&nbsp;&nbsp;Services</td>
    <td id="share_serv"></td><td id="share_serv_date"></td>
    </tr>

    <tr>
    <td>PIB (en milliards monnaie locale)</td>
    <td id="GDP_LCU"></td><td id="GDP_LCU_date"></td>
    </tr>

    <tr>
    <td>PIB (en millards de US$ de 2011)</td>
    <td id="GDP_PPP"></td><td id="GDP_PPP_date"></td>
    </tr>

    <tr>
    <td>Taux d'ouverture de l'économie (imports + exports) / PIB </td>
    <td id="ouverture"></td><td id="ouverture_date"></td>
    </tr>

    <tr>
    <td>Taux de couverture des importations par les exportations (biens et services), en milliards USD</td>
    <td id="exp_imp"></td><td id="exp_imp_date"></td>
    </tr>

    <tr>
    <td>Dette publique totale (%PIB)  </td>
    <td id="debt"></td><td id="debt_date"></td>
    </tr>

    <tr>
    <td>&nbsp;&nbsp;&nbsp;dont dette extérieure publique (%PNB) </td>
    <td id="ext_debt"></td><td id="ext_debt_date"></td>
    </tr>
    
    <tr><th><h2>Indicateurs économiques et financiers conjoncturels <hr></h2></th></tr>

    <tr>
    <td>Taux de croissance annuel réel du PIB </td>
    <td id="GDPg_m4"></td><td id="GDPg_m3"></td><td id="GDPg_m2"></td> <td id="GDPg_m1"></td> <td id="GDPg"></td>
    </tr>

    <tr>
    <td>Taux de croissance annuel réel du PIB par tête</td>
    <td id="GDP_PCg_m4"></td><td id="GDP_PCg_m3"></td><td id="GDP_PCg_m2"></td> <td id="GDP_PCg_m1"></td> <td id="GDP_PCg"></td>
    </tr>

    <tr>
    <td>Investissement intérieur (% PIB)</td>
    <td id="invest_m4"></td><td id="invest_m3"></td><td id="invest_m2"></td> <td id="invest_m1"></td> <td id="invest"></td>
    </tr>

    <tr>
    <td>Epargne nationale brute (% PIB)</td>
    <td id="saving_m4"></td><td id="saving_m3"></td><td id="saving_m2"></td> <td id="saving_m1"></td> <td id="saving"></td>
    </tr>

    <tr>
    <td>Prix à la consommation (% de variation)</td>
    <td id="price_m4"></td><td id="price_m3"></td><td id="price_m2"></td> <td id="price_m1"></td> <td id="price"></td>
    </tr>

    <tr>
    <td>Exportation de biens et services (% d'augmentation annuel sur les valeurs en USD)</td>
    <td id="Export_m4"></td><td id="Export_m3"></td><td id="Export_m2"></td> <td id="Export_m1"></td> <td id="Export"></td>
    </tr>

    <tr>
    <td>Solde du compte courant (% PIB)</td>
    <td id="balance_m4"></td><td id="balance_m3"></td><td id="balance_m2"></td> <td id="balance_m1"></td> <td id="balance"></td>
    </tr>  

    <tr>
    <td>Réserves officielles brutes (en mois d'importations)</td>
    <td id="reserve_m4"></td><td id="reserve_m3"></td><td id="reserve_m2"></td> <td id="reserve_m1"></td> <td id="reserve"></td>
    </tr>

    <tr>
    <td>Taux de change (monnaie locale/US$, moyenne sur la période)</td>
    <td id="exchange_rate_m4"></td><td id="exchange_rate_m3"></td><td id="exchange_rate_m2"></td> <td id="exchange_rate_m1"></td> <td id="exchange_rate"></td>
    </tr>

    <tr>
    <td>Taux de change effectif réel (% de variation)</td>
    <td id="real_exchge_m4"></td><td id="real_exchge_m3"></td><td id="real_exchge_m2"></td> <td id="real_exchge_m1"></td> <td id="real_exchge"></td>
    </tr>

    <tr>
    <td>Services de la dette publique (% PIB)</td>
    <td id="debt_serv_m4"></td><td id="debt_serv_m3"></td><td id="debt_serv_m2"></td> <td id="debt_serv_m1"></td> <td id="debt_serv"></td>
    </tr>

    <tr>
    <td>Intérêts de la dette publique (% revenu)</td>
    <td id="interest_payment_m4"></td><td id="interest_payment_m3"></td><td id="interest_payment_m2"></td> <td id="interest_payment_m1"></td> <td id="interest_payment"></td>
    </tr>

    <tr>
    <td>Recettes budgétaires (% PIB, hors dons)</td>
    <td id="revenue_m4"></td><td id="revenue_m3"></td><td id="revenue_m2"></td> <td id="revenue_m1"></td> <td id="revenue"></td>
    </tr>

    <tr>
    <td>Solde budgétaire primaire (% PIB)</td>
    <td id="solde_budg_prim_m4"></td><td id="solde_budg_prim_m3"></td><td id="solde_budg_prim_m2"></td> <td id="solde_budg_prim_m1"></td> <td id="solde_budg_prim"></td>
    </tr>
    
    <tr>
    <td>Solde budgétaire global (% PIB)</td>
    <td id="solde_budg_glob_m4"></td><td id="solde_budg_glob_m3"></td><td id="solde_budg_glob_m2"></td> <td id="solde_budg_glob_m1"></td> <td id="solde_budg_glob"></td>
    </tr>

    <tr>
    <td>Taux d'intérêt réel</td>
    <td id="real_interest_rate_m4"></td><td id="real_interest_rate_m3"></td><td id="real_interest_rate_m2"></td> <td id="real_interest_rate_m1"></td> <td id="real_interest_rate"></td>
    </tr>

    <tr>
    <td>Crédit au secteur privé (% PIB)</td>
    <td id="credit_ps_m4"></td><td id="credit_ps_m3"></td><td id="credit_ps_m2"></td> <td id="credit_ps_m1"></td> <td id="credit_ps"></td>
    </tr>

    <tr>
    <td>Masse monétaire (M2, % PIB)</td>
    <td id="money_m4"></td><td id="money_m3"></td><td id="money_m2"></td> <td id="money_m1"></td> <td id="money"></td>
    </tr>
    <tr>
    <td style="border-bottom: 0px solid #f1f1f1; text-align:right" colspan="6"><a href="http://afd.countrydashboards.com/glance/source.html" target="_blank"><i><b>Data Sources</b></i></a></td>
    </tr>
    </table>
    </td>
    </table>    
   
    </body></html>

    '''

    #open an handle
    f = open('glance_'+iso3+'.html','w')
    #write the content within the handle
    file_content = Template(html).safe_substitute(Input)
    f.write(file_content)
    f.close()
    #generate an html file
    filename='glance_'+iso3+'.html'
